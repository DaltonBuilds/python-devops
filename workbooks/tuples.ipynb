# %%
proxmox_host_port = ("192.168.40.50", 8006)

print(f"HOST: {proxmox_host_port[0]}, PORT: {proxmox_host_port[1]}")
print(type(proxmox_host_port))
# Out:
# HOST: 192.168.40.50, PORT: 8006
# <class 'tuple'>

# %%
service_endpoint = ("auth-server.dev.local", 80)

print(f"Hostname: {service_endpoint[0]}")
print(f"Port: {service_endpoint[1]}")
# Out:
# Hostname: auth-server.dev.local
# Port: 80

# %%
# service_endpoint[0] = "backend-01.dev.local" <-- Cannot change this since it is a tuple!
