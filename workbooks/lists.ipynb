# %%
servers = ["nginx-01", "fastapi-01", "nfs-01"]

for i in servers:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
print(servers[-1])
# Out:
# nfs-01

# %%
ports = [80, 443, 8080]

ports.append(5000)

ports.remove(80)

ports.insert(2, 3000)

print(ports)
# Out:
# [443, 8080, 3000, 5000]

# %%
deployment_targets = ["eu-west-1", "ap-southeast-2", "us-west-1"]

deployment_targets.append("us-east-2")
print(deployment_targets)

deployment_targets[1] = "eu-east-1"
print(deployment_targets)
# Out:
# ['eu-west-1', 'ap-southeast-2', 'us-west-1', 'us-east-2']
# ['eu-west-1', 'eu-east-1', 'us-west-1', 'us-east-2']
